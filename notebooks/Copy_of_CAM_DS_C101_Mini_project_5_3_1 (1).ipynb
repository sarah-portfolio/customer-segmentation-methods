# %% [markdown]
# **First things first** - please go to 'File' and select 'Save a copy in Drive' so that you have your own version of this activity set up and ready to use.
# Remember to update the portfolio index link to your own work once completed!

# %% [markdown]
# # Mini-project 5.3 Detecting the anomalous activity of a ship’s engine
#
# **Welcome to your first mini-project: Detecting the anomalous activity of a ship’s engine!**
#
# This mini-project allows you to dive deep into a real-world challenge, applying and honing the data science skills you've been cultivating so far. In this immersive exploration into detecting the anomalous activity of a ship’s engine, you can practically apply the concepts you've learned over the past few weeks.
#
# A poorly maintained ship engine in the supply chain industry can lead to inefficiencies, increased fuel consumption, higher risks of malfunctions, and potential safety hazards. Your challenge in this project is to apply critical thinking and ML concepts to design and implement a robust anomaly detection model.
#
# Please set aside approximately **12 hours** to complete the mini-project by **Monday, 20 May 2024, at 5 p.m. (UK Time)**.
#
# <br></br>
#
# ## **Business context**
# You are provided with a real data set to identify anomalous activity in a ship’s engine functionality (Devabrat,  2022). As you work through this project, keep in mind that, typically speaking, anomalies would make up a minority of the data points (i.e., about 1% to 5% of the data points would be anomalies).
#
# The data set contains six important features continuously monitored to evaluate the engine's status as ‘good’ or ‘bad’. These features are:
# - **Engine rpm (revolutions per minute):** A high rpm indicates the engine is operating at a higher speed than designed for prolonged periods, which can lead to overheating, excessive wear, and eventual failure. A low rpm could signal a lack of power, issues with fuel delivery, or internal mechanical problems.
# - **Lubrication oil pressure:** Low lubrication oil pressure indicates insufficient lubrication, leading to increased friction, overheating, and engine damage. A high lubrication oil pressure could signal a blockage in the oil delivery system, potentially causing seal or gasket failure.
# - **Fuel pressure:** High fuel pressure can cause poor engine performance and incomplete combustion, indicating fuel pump or filter issues. A low fuel pressure may result in excessive fuel consumption, poor emissions, or damage to the fuel injectors.
# - **Coolant pressure:** Low coolant pressure indicates a potential leak in the cooling system or a coolant pump failure, risking engine overheating. A high coolant pressure could be a sign of a blockage in the cooling system or a failing head gasket, which can also lead to overheating.
# - **Lubrication oil temperature:** High lubrication oil temperature suggests the oil is overheating, which can degrade its lubricating properties and lead to engine damage. A low lubrication oil temperature may indicate it is not reaching its optimal operating temperature, potentially causing inadequate lubrication.
# - **Coolant temperature:** High coolant temperature signals overheating, which various issues, including a failed thermostat, coolant leak, or insufficient coolant flow can cause. A low coolant temperature could suggest the engine is not reaching its optimal operating temperature, affecting performance and efficiency.
#
# Issues with engines could lead to engine malfunctions, potential safety hazards, and downtime (e.g. delayed deliveries), resulting in the breakdown of a ship’s overall functionality, consequently impacting the business, such as affecting revenue via failure to deliver goods. By predicting timely maintenance, the business aims to increase profit by reducing downtime, reducing safety risks for the crew, limiting fuel consumption, and increasing customer satisfaction through timely deliveries.
#
# Your task is to develop a robust anomaly detection system to protect a company’s shipping fleet by evaluating engine functionality. Therefore, you’ll explore the data and:
# - employ preprocessing and feature engineering
# - perform model training, anomaly detection, post-processing, and refinement.
#
# You must prepare a report illustrating your insights to the prospective stakeholders, showing how your solution will save the business money and build trust with its stakeholders. At this stage of the project, the main question you need to consider is:
# - What insights can be gained from the data, and what recommendations can be made to the company based on these insights? For example, which features need to be monitored closely, and what are the thresholds for anomalous observations? Which statistical or ML technique is the best for anomaly detection based on **this data set**, and which feature (univariate approach) or combination of features (multivariate approach) can predict maintenance?
#
# <br></br>
#
# > **Disclaimer**
# >
# > Please note that although a real-life data set was provided, the business context in this project is fictitious. Any resemblance to companies and persons (living or dead) is coincidental. The course designers and hosts assume no responsibility or liability for any errors or omissions in the content of the business context and data sets. The information in the data sets is provided on an 'as is' basis with no guarantees of completeness, accuracy, usefulness, or timeliness.
#
# <br></br>
#
# ## **Objective**
# By the end of this mini-project, you will be able to understand and apply statistical and ML methods for detecting anomalies.
#
# In the Notebook, you will:
# - explore the data set
# - preprocess the data and conduct feature engineering
# - apply statistical techniques to detect anomalies
# - use ML algorithms to detect anomalies.
#
# You will also write a report summarising the results of your findings and recommendations.
#
# <br></br>
#
# ## **Assessment criteria**
# By completing this project, you will be able to provide evidence that you can:
# - demonstrate enhanced problem-solving skills and proposed strategic solutions by systematically analysing complex organisational challenges
# - identify meaningful patterns in complex data to evidence advanced critical and statistical thinking skills
# - select statistical techniques appropriate to a solutions design approach and evidence the ability to evaluate their effectiveness
# - demonstrate enhanced data representation and improved model performance by systematically implementing relevant techniques
# - design innovative solutions through critically selecting, evaluating and implementing effective unsupervised learning techniques.
#
# <br></br>
#
# ## **Project guidance**
# 1. Import the required libraries and data set with the provided URL.
# 2. View the DataFrame and perform EDA, including identifying missing or duplicate values.
# 3. Generate the descriptive statistics of the data, including:
#  - observing the mean for each feature
#  - identifying the median
#  - idenitfying the range values beyond the 95th percentile for at least two features.
# 4. Visualise the data to determine the distribution and extreme values.
# 5. Perform anomaly detection with a statistical method and identify possible anomalies. Specifically:
#   - Use the interquartile range (IQR) method to identify outliers for each feature.
#   - Create a new column (corresponding to each feature) that will indicate (in binary – 0,1) if the value of that feature is an outlier as per IQR calculations.
#   - Use IQR to identify a sample as an outlier only if three or more of the features fall under an outlier category for a particular sample.
#   - Use IQR to identify a sample as an outlier only if all the features fall under an outlier category for a particular sample.
#   - Record your thoughts and oberservations.
# 6. Perform anomaly detection with ML models:
#   - Perform feature scaling to prepare the data for ML algorithms.
#   - Using one-class SVM,
#     - identify possible anomalies
#     - visualise the output in 2D after performing PCA and ensure the outliers are in a different colour
#     - apply different combinations of parameter settings to improve the model's performance
#     - record your insights about the use of this method.
#   - Using Isolation Forest,
#     - identify possible anomalies
#     - visualise the output in 2D after performing PCA and ensure the outliers are in a different colour
#     - apply different combinations of parameter settings to improve the model's performance
#     - record your insights about the use of this method.
# 7. Document your approach and major inferences from the data analysis and describe which method (and parameters) provided the best results and why.
# 8. When you’ve completed the activity:
#   - Download your completed Notebook as an IPYNB (Jupyter Notebook) or PY (Python) file. Save the file as follows: LastName_FirstName_CAM_C101_W5_Mini-project.
#   - Prepare a detailed report (between 800-1000 words) that includes:
#     - an overview of your approach
#     - a description of your analysis
#     - an explanation of the insights you identified
#     - a summary of which method gave the best results
#     - a clear visualisation of your anomaly detection approach
#     - an explanation of whether the 2D plot describes observations are classified as outliers.
#   - Save the document as a PDF named according to the following convention: LastName_FirstName_CAM_C101_W5_Mini-project.pdf.
#   - You can submit your files individually or as a ZIP file. If you upload a ZIP file, use the correct naming convention: LastName_FirstName_CAM_C101_W5_Mini-project.zip.
#   - Submit your Notebook and PDF document by **Monday, 20 May 2024, at 5 p.m. (UK Time)**.
#
# <br></br>
# > **Declaration**
# >
# > By submitting your project, you indicate that the work is your own and has been created with academic integrity. Refer to the Cambridge plagiarism regulations.

# %% [markdown]
# > Start your activity here. Select the pen from the toolbar to add your entry.

# %%
# Problem Statement: The anomalies in data that record a poorly maintained ship's engine functions require a focus on pressure (oil, coolant, fuel) and temperature (coolant, oil). The visualization of the data

# %%
# 1. Import the required libraries and data set with the provided URL.
# Import the necessary libraries.

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest
from scipy.stats import pearsonr, spearmanr
from itertools

# %%
# URL to import data set from GitHub.

url = 'https://raw.githubusercontent.com/fourthrevlxd/cam_dsb/main/engine.csv'

# Read the CSV file into a new DataFrame.
df = pd.read_csv(url)

# Display the first few rows of the DataFrame.
print(df.shape)
df.head()
# Out:
# (19535, 6)
#    Engine rpm  Lub oil pressure  Fuel pressure  Coolant pressure  \
# 0         682          2.391656       4.617196          2.848982
# 1         605          5.466877       6.424361          5.727520
# 2         658          3.434232       3.680896          1.678708
# 3         749          2.094656       7.120927          1.639670
# 4         676          3.538228       5.956472          3.225336
#
#    lub oil temp  Coolant temp
# 0     76.272417     69.884609
# 1     73.222679     74.907314
# 2     88.089916     78.704806
# 3     77.661625     82.386700
# 4     75.226352     67.153220

# %%
#2. Identify missing or duplicate values.

df.info()
df.isnull().sum()
df.duplicated().sum()
# data info indicates that there are no non-null values and no duplicAtE VALUES

df['Coolant pressure'].isnull()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19535 entries, 0 to 19534
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Engine rpm        19535 non-null  int64
#  1   Lub oil pressure  19535 non-null  float64
#  2   Fuel pressure     19535 non-null  float64
#  3   Coolant pressure  19535 non-null  float64
#  4   lub oil temp      19535 non-null  float64
#  5   Coolant temp      19535 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 915.8 KB
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19530    False
# 19531    False
# 19532    False
# 19533    False
# 19534    False
# Name: Coolant pressure, Length: 19535, dtype: bool

# %%
# All columns are numeric values, all float measurements (i.e. continuous numeric) with the exception of engine rpm, which is integer
# Make engine rpm into a float because it means data could be easier to work with and is less likely to result in errors or limit statistical test opportunities

# Convert the 'integers' column to float
df['Engine rpm'] = df['Engine rpm'].astype(float)

print(df.dtypes)

# additional changes to the data types is unecessary because ML algorithms can work with numeric data of one type
# Out:
# Engine rpm          float64
# Lub oil pressure    float64
# Fuel pressure       float64
# Coolant pressure    float64
# lub oil temp        float64
# Coolant temp        float64
# dtype: object

# %%
# Convert the figures to a more accessible measurement - 3 decimal places
df = df.round(decimals=3)

df
# Out:
#        Engine rpm  Lub oil pressure  Fuel pressure  Coolant pressure  \
# 0           682.0             2.392          4.617             2.849
# 1           605.0             5.467          6.424             5.728
# 2           658.0             3.434          3.681             1.679
# 3           749.0             2.095          7.121             1.640
# 4           676.0             3.538          5.956             3.225
# ...           ...               ...            ...               ...
# 19530       681.0             3.599          7.301             1.083
# 19531       580.0             2.243          5.242             1.471
# 19532       616.0             3.310          3.788             6.001
# 19533      1163.0             2.732          3.704             2.952
# 19534       695.0             2.515          6.355             2.689
#
#        lub oil temp  Coolant temp
# 0            76.272        69.885
# 1            73.223        74.907
# ...

# %%
# Draw the six variables
columns_to_count = ['Engine rpm', 'Lub oil pressure', 'Fuel pressure', 'Coolant pressure', 'lub oil temp', 'Coolant temp']

# Create a 2x3 grid of subplots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Plot histograms for each variable
for i, column in enumerate(columns_to_count):
    row = i // 3
    col = i % 3
    axes[row, col].hist(df[column])
    axes[row, col].set_title(column)
    axes[row, col].set_xlabel('Value')
    axes[row, col].set_ylabel('Frequency')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# correlation plots for engine rpm v fuel pressure, lub oil pressure + fuek pressure, also coolant temp v fuel pressure

# %%
plt.scatter(df['Coolant pressure'], df['lub oil temp'], c='green')

# %%
# Function to plot multiple variables on a line graph (though could require normalization/standardization)

def plot_lines(df, engine_rpm, columns_to_count, colors):
  """
  Plots multiple lines on a single plot.

  Args:
    df: DataFrame containing the data.
    engine_rpm: Name of the variable for the x-axis.
    columns_to_count: List of names of the variables for the y-axis.
    colors: List of colors for the lines.
  """
  plt.figure(figsize=(10, 6))
  for column, color in zip(columns_to_count, colors):
    plt.plot(df[engine_rpm], df[column], c=color, label=column)
  plt.xlabel(engine_rpm)
  plt.ylabel('Other Variables')
  plt.title(f'Relationship between {engine_rpm} and Other Variables')
  plt.legend()
  plt.grid(True)
  plt.show()

# Example usage:
engine_rpm = 'Engine rpm'
columns_to_count = ['Lub oil pressure', 'Fuel pressure', 'Coolant pressure', 'lub oil temp', 'Coolant temp']
colors = ['purple', 'orange', 'green', 'red', 'blue', 'brown']
plot_lines(df, engine_rpm, columns_to_count, colors)
# Consistent applications of fuel pressure and coolant pressure when the engine performs - the system recognises that the requirement exists, but is it delivering fuel and / or coolant?

# Coolant temperature is 85 (29.44 degrees celsius) to 95 (35 degrees Celsius) in the normal rangw. Significant temperature records are held that indicate the Coolant does not remain within or close to those boundaries.

# %%
# Plot the results.
plt.figure(figsize=(15, 7))

# Plot the raw data with outliers.
plt.subplot(1, 2, 1)
plt.scatter(df['Fuel pressure'], df['Coolant pressure'])
plt.ylim(0, 8)  # Fix the y-axis scale.
plt.title('Raw data')
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Use the IQR method to identify the outliers.
Q1 = df['Coolant temp'].quantile(0.25)
Q3 = df['Coolant temp'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove the outliers.
df_clean_ct = df[(df['Coolant temp'] > lower_bound) & (df['Coolant temp'] < upper_bound)]
df_clean_ct
# Out:
#        Engine rpm  Lub oil pressure  Fuel pressure  Coolant pressure  \
# 0           682.0             2.392          4.617             2.849
# 1           605.0             5.467          6.424             5.728
# 2           658.0             3.434          3.681             1.679
# 3           749.0             2.095          7.121             1.640
# 4           676.0             3.538          5.956             3.225
# ...           ...               ...            ...               ...
# 19530       681.0             3.599          7.301             1.083
# 19531       580.0             2.243          5.242             1.471
# 19532       616.0             3.310          3.788             6.001
# 19533      1163.0             2.732          3.704             2.952
# 19534       695.0             2.515          6.355             2.689
#
#        lub oil temp  Coolant temp
# 0            76.272        69.885
# 1            73.223        74.907
# ...

# %%
def clean_and_calculate_iqr(df, columns):
  """
  Cleans outliers from specified columns in a DataFrame using IQR and prints IQR values.

  Args:
    df: DataFrame containing the data.
    columns: List of column names to clean.

  Returns:
    A new DataFrame with outliers removed from the specified columns.
  """
  df_clean = df.copy()
  for col in columns:
    Q1 = df_clean[col].quantile(0.25)
    Q3 = df_clean[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_clean = df_clean[(df_clean[col] >= lower_bound) & (df_clean[col] <= upper_bound)]
    print(f"IQR for {col}: {IQR}")
  return df_clean

# Use the defined function to calculate iteratively the IQR of columns_to_clean:
columns_to_clean = ['Coolant temp', 'Lub oil pressure', 'Fuel pressure', 'lub oil temp', 'Coolant pressure']
df_clean = clean_and_calculate_iqr(df, columns_to_clean
# Out:
# IQR for Coolant temp: 9.020500000000013
# IQR for Lub oil pressure: 1.5359999999999996
# IQR for Fuel pressure: 2.8289999999999997
# IQR for lub oil temp: 2.3377499999999998
# IQR for Coolant pressure: 1.2439999999999998

# %%
# Plot the raw data for Coolant temperature
plt.figure(figsize=(15, 7))

plt.subplot(1,2,1)
sns.boxplot(df['Coolant temp'])
plt.title('Coolant temp Raw data')

# Plot the cleaned data.
plt.subplot(1,2,2)
sns.boxplot(df_clean_ct['Coolant temp'])
plt.title('Coolant temp Cleaned data')

# View the plot.
plt.show()

# %%
# Plot the raw and clean data for all features using the boxplot method
def plot_raw_and_clean_boxplots(df, df_clean, columns):
  """
  Plots raw and cleaned boxplots for specified columns.

  Args:
    df: DataFrame containing the raw data.
    df_clean: DataFrame containing the cleaned data.
    columns: List of column names to plot.
  """
  for col in columns:
    plt.figure(figsize=(15, 7))

    plt.subplot(1, 2, 1)
    sns.boxplot(df[col])
    plt.title(f'{col} Raw Data')

    plt.subplot(1, 2, 2)
    sns.boxplot(df_clean[col])
    plt.title(f'{col} Cleaned Data')

    plt.show()

# Example usage:
columns_to_plot = ['Coolant temp', 'Lub oil pressure', 'Fuel pressure', 'lub oil temp', 'Coolant pressure']
plot_raw_and_clean_boxplots(df, df_clean, columns_to_plot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-165621d9b87b> in <cell line: 26>()
#      24 # Example usage:
#      25 columns_to_plot = ['Coolant temp', 'Lub oil pressure', 'Fuel pressure', 'lub oil temp', 'Coolant pressure']
# ---> 26 plot_raw_and_clean_boxplots(df, df_clean, columns_to_plot)
#
# NameError: name 'df' is not defined

# %%
def plot_raw_and_clean_linreg(df, df_clean, col1, col2, col3, col4, col5):
  """
  Plots raw and cleaned linear regression models for two pairs of columns.

  Args:
    df: DataFrame containing the raw data.
    df_clean: DataFrame containing the cleaned data.
    col1: Name of the first column.
    col2: Name of the second column.
    col3: Name of the third column.
    col4: Name of the fourth column.
    col5: Name of the fifth column.
  """

  # Plot for the first pair of columns
  plt.figure(figsize=(15, 7))

  # With outliers.
  plt.subplot(1, 2, 1)
  plt.scatter(df[col1], df[col2], label='Data')

  lr_raw = LinearRegression()
  lr_raw.fit(df[[col1]], df[col2])
  y_pred_raw = lr_raw.predict(df[[col1]])
  plt.plot(df[col1], y_pred_raw, color='red', label='Line of best fit')

  # Without outliers.
  plt.subplot(1, 2, 2)
  plt.scatter(df_clean[col1], df_clean[col2], label='Data')

  lr_clean = LinearRegression()
  lr_clean.fit(df_clean[[col1]], df_clean[col2])
  y_pred_clean = lr_clean.predict(df_clean[[col1]])
  plt.plot(df_clean[col1], y_pred_clean, color='red', label='Line of Best Fit')

  mse_clean = mean_squared_error(df_clean[col2], y_pred_clean)
  r2_clean = r2_score(df_clean[col2], y_pred_clean)
  plt.title('Cleaned data')
  plt.legend()
  plt.text(df_clean[col1].min(), df_clean[col2].min(), f'MSE: {mse_clean:.2f}\nR-squared: {r2_clean:.2f}', fontsize=12)

  plt.show()

  # Plot for the second pair of columns (using col3, col4 and col5)
  plt.figure(figsize=(15, 7))

  # With outliers.
  plt.subplot(1, 2, 1)
  plt.scatter(df[col3], df[col4], label='Data')

  lr_raw = LinearRegression()
  lr_raw.fit(df[[col3]], df[col4])
  y_pred_raw = lr_raw.predict(df[[col3]])
  plt.plot(df[col3], y_pred_raw, color='red', label='Line of best fit')

  mse_raw = mean_squared_error(df[col4], y_pred_raw)
  r2_raw = r2_score(df[col4], y_pred_raw)
  plt.title('Raw data')
  plt.legend()
  plt.text(df[col3].min(), df[col4].min(), f'MSE: {mse_raw:.2f}\nR-squared: {r2_raw:.2f}', fontsize=12)

  # Without outliers.
  plt.subplot(1, 2, 2)
  plt.scatter(df_clean[col3], df_clean[col4], label='Data')

  lr_clean = LinearRegression()
  lr_clean.fit(df_clean[[col3]], df_clean[col4])
  y_pred_clean = lr_clean.predict(

# %%
# Retrieve the equations of the lines.

# Coefficients of the raw line
slope = lr_raw.coef_[0]
intercept = lr_raw.intercept_

# Coefficients of the clean line (no outliers)
slope_clean = lr_clean.coef_[0]
intercept_clean = lr_clean.intercept_

print(f"Equation of the cleaned data line: y = {slope_clean:.2f}x + {intercept_clean:.2f}")
print(f"Equation of the raw data line: y = {slope:.2f}x + {intercept:.2f}"

# %%
# https://buysinopec.com/blogs/news/iso-32-46-68-100-hydraulic-oil-temperature-range-hydraulic-oil-specification-chart

# Create a new column - is the coolant range between 85 and 95 [is this F?)

label = df['Coolant temp']
label.head()
label.unique()

# %%
# https://www.marineinsight.com/guidelines/general-overview-of-central-cooling-system-on-ships/#:~:text=The%20outlet%20temperature%20of%20the,system%20into%20the%20HT%20system.

# make a new column - is the coolant range between 85 and 95 [is this F?)

label = df['Coolant temp']
label.head()
label.unique()

.applyto('Coolant performance') # Taking the range of 85-95 degrees as the operating temperature of the coolant, a new column was created to examine this variable in greater detail, 'Coolant Performance'; a binary classification of values as within or external to the recommended temperature ranges

# Also a higher and lower than the optiml performance threshold level column

# Visualise the data.

# Create a catplot.
sns.catplot(x ="Coolant temp", hue ="Coolant performance",
            kind ="count", data = df)
# Out:
#   File "<ipython-input-13-6ac368e81c2c>", line 9
#     .applyto('Coolant performance') # Taking the range of 85-95 degrees as the operating temperature of the coolant, a new column was created to examine this variable in greater detail, 'Coolant Performance'; a binary classification of values as within or external to the recommended temperature ranges
#     ^
# SyntaxError: invalid syntax

# %%
# Assuming 'df' is your DataFrame
# Replace with the actual names of your six columns
columns_to_count = ['Engine rpm', 'Lub oil pressure', 'Fuel pressure', 'Coolant pressure', 'lub oil temp', 'Coolant temp']

for column in columns_to_count:
    min_value = df.min()
    max_value = df.max()

print(f"Minimum values in each:\n{min_value}")
print(f"Maximum values in each column:\n{max_value}") # REMOVE OUTLIERS AND RUN CODE CELL AGAIN
# Out:
# Minimum values in each:
# Engine rpm          61.000
# Lub oil pressure     0.003
# Fuel pressure        0.003
# Coolant pressure     0.002
# lub oil temp        71.322
# Coolant temp        61.673
# dtype: float64
# Maximum values in each column:
# Engine rpm          2239.000
# Lub oil pressure       7.266
# Fuel pressure         21.138
# Coolant pressure       7.479
# lub oil temp          89.581
# Coolant temp         195.528
# dtype: float64

# %%
# Create a catplot.
sns.catplot(x ='Coolant temp', hue ='Operational performance level',
            kind ='count', col = "Coolant High/Low temp", data = df]

# %%
# Create a third catplot which should keep the high/low temp feature and apply a new column, using one hot encoding, for oil temperature.
sns.catplot(x ='Coolant temp', hue ='Operational performance level',
            kind ='count', col = "Coolant High/Low temp", data = df]

# %%
# Use figsize to set the figure size.
plt.figure(figsize=(15, 7))
sns.heatmap(df.corr(), annot=True)

plt.show()

# %%
# Visualise data with scatterplots
plt.figure(figsize=(12, 5))

# Plot the raw data with outliers.
plt.subplot(1, 2, 1)
plt.scatter(df['Lub oil pressure'], df['lub oil temp'], label='Lub oil temp v lub pressure')
plt.ylim(0, 100)  # Fix the y-axis scale.
plt.title('correlation plot with oil data ranges and earning level')
plt.legend()

# Add the horizontal line at Coolant temp = 60
plt.axhline(y=60, color='red', linestyle='-', linewidth=2, label='Warning: Safe temperature exceeded at 60 degrees')

# Plot the raw data with outliers.
plt.subplot(1, 2, 2)
plt.scatter(df['Coolant pressure'], df['Coolant temp'], label='Coolant temp v Coolant pressure', c='red')
plt.ylim(0, 100)
plt.title('correlation plot with coolant data ranges')
plt.legend()
plt.tight_layout()

# Set labels and title
plt.grid(True)
plt.show()

# %%
# Visualise engine data with histogram.
plt.figure(figsize=(12, 5))

# Plot the raw data with outliers.
plt.subplot(1, 2, 1)
sns.histplot(data = df['Engine rpm'], kde = True)
plt.title('engine rpm raw')

plt.subplot(1, 2, 2)
sns.boxplot(x = df['Engine rpm'])
plt.title('engine rpm raw')
plt.show()

plt.tight_layout()

# Not a normal distribution, skew to the left.
# Explore potential outliers above and below the lower and upper quartiles

# %%
# Create a scatterplot.
# Using information provided, lub oil temp is consistently high at low - high Lub oil pressure

plt.scatter(df['Lub oil pressure'],
            df['lub oil temp'],
            c='b',
            marker='o',
            s=15)

plt.title('Scatterplot')
plt.xlabel('Lub oil pressure')
plt.ylabel('lub oil temp')

# Show the plot.
plt.show()

# dominant clustering 1.7 - 4.8, temp 71.0 - 88.2 and 72.0 - 89.2 no trend other than above safe operating level - alarm?
pearson_corr, _= pearsonr(df['lub oil temp'], ['Lub oil pressure'])
print(f"Pearson correlation: {pearson_corr}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-6d351681d539> in <cell line: 18>()
#      16
#      17 # dominant clustering 1.7 - 4.8, temp 71.0 - 88.2 and 72.0 - 89.2 no trend other than above safe operating level - alarm?
# ---> 18 pearson_corr, _= pearsonr(df['lub oil temp'], ['Lub oil pressure'])
#      19 print(f"Pearson correlation: {pearson_corr}")
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py in pearsonr(x, y, alternative, method)
#    4719     n = len(x)
#    4720     if n != len(y):
# -> 4721         raise ValueError('x and y must have the same length.')
#    4722
#    4723     if n < 2:
#
# ValueError: x and y must have the same length.

# %%
# Visualise possible correlation.
plt.figure(figsize=(10, 8))

#H1: Oil temperature rises as coolant pressure decreases

# Create a scatterplot.
plt.scatter(df['lub oil temp'],
            df['Coolant pressure'],
            c='b')

plt.title('Scatterplot')
plt.xlabel('Lub oil temp')
plt.ylabel('Coolant pressure')

# Show the plot.
plt.show()

# Suggests a third factor - plotting other combinations of correlation suspected
pearson_corr, _= pearsonr(df['lub oil temp'], ['Coolant pressure'])
print(f"Pearson correlation: {pearson_corr}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-aa39ded21627> in <cell line: 19>()
#      17
#      18 # Suggests a third factor - plotting other combinations of correlation suspected
# ---> 19 pearson_corr, _= pearsonr(df['lub oil temp'], ['Coolant pressure'])
#      20 print(f"Pearson correlation: {pearson_corr}")
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py in pearsonr(x, y, alternative, method)
#    4719     n = len(x)
#    4720     if n != len(y):
# -> 4721         raise ValueError('x and y must have the same length.')
#    4722
#    4723     if n < 2:
#
# ValueError: x and y must have the same length.

# %%
# Visualise possible correlation.
plt.figure(figsize=(10, 8))

# Create a scatterplot.
plt.scatter(df['Fuel pressure'],
            df['Coolant pressure'],
            c='b')

plt.title('Scatterplot')
plt.xlabel('Fuel pressure')
plt.ylabel('Coolant pressure')

# Show the plot.
plt.show()

# No correlation - though when fuel pressure is low coolant is low. Almost symmetric distribution.
pearson_corr, _= pearsonr(df['Fuel pressure'], ['Coolant pressure'])
print(f"Pearson correlation: {pearson_corr}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-42782489189f> in <cell line: 17>()
#      15
#      16 # No correlation - though when fuel pressure is low coolant is low. Almost symmetric distribution.
# ---> 17 pearson_corr, _= pearsonr(df['Fuel pressure'], ['Coolant pressure'])
#      18 print(f"Pearson correlation: {pearson_corr}")
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py in pearsonr(x, y, alternative, method)
#    4719     n = len(x)
#    4720     if n != len(y):
# -> 4721         raise ValueError('x and y must have the same length.')
#    4722
#    4723     if n < 2:
#
# ValueError: x and y must have the same length.

# %%
# Visualise possible correlation.
plt.figure(figsize=(5, 4))

# Create a scatterplot.
plt.scatter(df['Coolant temp'],
            df['Coolant pressure'],
            c='b')

plt.title('Scatterplot')
plt.xlabel('Coolant temp')
plt.ylabel('Coolant pressure')

# Show the plot.
plt.show()

# Find the outliers at 119 and 196 and explore arguments in favour of their removal

pearson_corr, _= pearsonr(df['Coolant temp'], ['Coolant pressure'])
print(f"Pearson correlation: {pearson_corr}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-a7d5233f84fb> in <cell line: 18>()
#      16 # Find the outliers at 119 and 196 and explore arguments in favour of their removal
#      17
# ---> 18 pearson_corr, _= pearsonr(df['Coolant temp'], ['Coolant pressure'])
#      19 print(f"Pearson correlation: {pearson_corr}")
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py in pearsonr(x, y, alternative, method)
#    4719     n = len(x)
#    4720     if n != len(y):
# -> 4721         raise ValueError('x and y must have the same length.')
#    4722
#    4723     if n < 2:
#
# ValueError: x and y must have the same length.

# %%
# Visualise possible correlation.
plt.figure(figsize=(5, 4))

# Create a scatterplot.
plt.scatter(df['Fuel pressure'],
            df['Lub oil pressure'],
            c='b')

plt.title('Scatterplot')
plt.xlabel('Lub oil pressure')
plt.ylabel('Fuel pressure')


# Show the plot.
plt.show()

pearson_corr, _= pearsonr(df['Fuel pressure'], ['lub oil pressure'])
print(f"Pearson correlation: {pearson_corr}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-b1099c6e99b0> in <cell line: 17>()
#      15 plt.show()
#      16
# ---> 17 pearson_corr, _= pearsonr(df['Fuel pressure'], ['lub oil pressure'])
#      18 print(f"Pearson correlation: {pearson_corr}")
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py in pearsonr(x, y, alternative, method)
#    4719     n = len(x)
#    4720     if n != len(y):
# -> 4721         raise ValueError('x and y must have the same length.')
#    4722
#    4723     if n < 2:
#
# ValueError: x and y must have the same length.

# %%
# Visualise possible correlation.
plt.figure(figsize=(5, 4))

# Create a scatterplot.
plt.scatter(df['Coolant temp'],
            df['lub oil temp'],
            c='b')

plt.title('Scatterplot')
plt.xlabel('Coolant temp')
plt.ylabel('lub oil temp')

# Show the plot.
plt.show()

# The outliers at 196 and 119 for coolant temp would be erroneous data since the lub oil temp is at 78 for the second and 77 for the former.

pearson_corr, _= pearsonr(df['Coolant temp'], ['lub oil temp'])
print(f"Pearson correlation: {pearson_corr}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-dac065419117> in <cell line: 18>()
#      16 # The outliers at 196 and 119 for coolant temp would be erroneous data since the lub oil temp is at 78 for the second and 77 for the former.
#      17
# ---> 18 pearson_corr, _= pearsonr(df['Coolant temp'], ['lub oil temp'])
#      19 print(f"Pearson correlation: {pearson_corr}")
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py in pearsonr(x, y, alternative, method)
#    4719     n = len(x)
#    4720     if n != len(y):
# -> 4721         raise ValueError('x and y must have the same length.')
#    4722
#    4723     if n < 2:
#
# ValueError: x and y must have the same length.

# %%
sns.pairplot(df[['Lub oil pressure', 'Fuel pressure', 'Coolant pressure', 'lub oil temp', 'Coolant temp']])

plt.show()
# Coolant temperature does not fall below 50 degrees and is negatively impacting the performance of the other four independent variables . Lub oil temp begins at approx 70 degrees. Coolant pressure is indiscriminantly high whether lub oil temp is high or low and this means that the coolant is having an adverse effect and it is essentially increasing in temperature - coolant pressure is high as a consequence of excessively high temperatures in both lubricating oil and coolant. Is there a leak in the lub oil transmission system? Has the excessively high oil temperatures burnt a hole in a pipe?

# %%
# Step_1: Identify the relevant input features
#Specify independent and dependent variables.
X = df[['Lub oil pressure', 'Fuel pressure', 'Coolant pressure', 'lub oil temp', 'Coolant temp']]

y = df['Engine rpm']

# Apply feature scaling
scaler = StandardScaler()
X = scaler.fit_transform(df)
y = scaler.fit_transform(df[['Engine rpm']])

# %%
# Create a linear regression model.
model = LinearRegression()

# Train the model.
model.fit(X, y)
# Make predictions.
y_pred = model.predict(X)

print(y_pred)
# Out:
# [[-0.40821185]
#  [-0.69595007]
#  [-0.49789649]
#  ...
#  [-0.65484461]
#  [ 1.38921787]
#  [-0.35963266]]

# %%
sns.kdeplot(y_pred.flatten()) # density estimation and plotting
plt.show()

# Normal distribution simulation:
# Mean and standard deviation
mean, std_dev = 0, 1
normal_sample = np.random.normal(mean, std_dev, 1000)

# Plot the normal distribution.
plt.figure(figsize=(8, 6))
sns.histplot(normal_sample, kde=True, color='orange')
plt.title('Normal Distribution (Mean=0, Std Dev=1)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# The data is negatively dispersed about the mean with a minor amount of kurtosis in the density plot and indicates that the data requires standardization for a true assessment of the central distribution.

# %%
# Train a linear regression model on the training data - all features (five)
model_all_features = LinearRegression()
model_all_features.fit(X, y)

# Only include four of the independent variables in the model (four).
# Train a linear regression model on the training data
X_train_missing_1 = X[0:19535]
model_missing_features_1 = LinearRegression()
model_missing_features_1.fit(X_train_missing_1, y)

# Only include three of the independent variables in the model (three).
# Train a linear regression model on the training data
X_train_missing_2 = X[0:19535]
model_missing_features_2 = LinearRegression()
model_missing_features_2.fit(X_train_missing_2, y)

# Only include two of the independent variables in the model (two).
# Train a linear regression model on the training data
X_train_missing_3 = X[0:19535]
model_missing_features_3 = LinearRegression()
model_missing_features_3.fit(X_train_missing_3, y)

# Only include one of the independent variables in the model (one).
# Train a linear regression model on the training data
X_train_missing_4 = X[0:19535]
model_missing_features_4 = LinearRegression()
model_missing_features_4.fit(X_train_missing_4, y)
# Out:
# LinearRegression()

# %%
# Making predictions that use the whole dataset available
y_pred_all = model_all_features.predict(X)

# Only four independent variables
y_pred_missing_1 = model_missing_features_1.predict(X_train_missing_1)

# Only three independent variable
y_pred_missing_2 = model_missing_features_2.predict(X_train_missing_2)

# Only two independent variables
y_pred_missing_3 = model_missing_features_3.predict(X_train_missing_3)

# Only one independent variable
y_pred_missing_4 = model_missing_features_4.predict(X_train_missing_4)

# %%
# Calculate the R-squared.
# All the independent variables
r2_all = r2_score(y, y_pred_all)

# Only four independent variables
r2_missing_1 = r2_score(y, y_pred_missing_1)

# Only three independent variable
r2_missing_2 = r2_score(y, y_pred_missing_2)

# Only two independent variables
r2_missing_3 = r2_score(y, y_pred_missing_3)

# Only one independent variable
r2_missing_4 = r2_score(y, y_pred_missing_4)

# %%
# Print R-squared.
# All the independent variables
print('R-squared ALL Features:', r2_all)

# Only four independent variables
print('R-squared Missing 1 Feature:', r2_missing_1)

# Only three independent variable
print('R-squared Missing 2 Features:', r2_missing_2)

# Only two independent variable
print('R-squared Missing 3 Features:', r2_missing_3)

# Only one independent variable
print('R-squared Missing 4 Features:', r2_missing_4)

# Must check this output but seems to indicate that the variance in engine rpm is explainable by each and every one of the features in the other five columns, the extent of the change that arises as a consequence of any single feature being present at this level of output. The regression line should span 0-1, a score of 1.0 entirely possible and indicating a perfect explanation of variability; in this instance, the expertise of the ship's engineer was used to select the data columns that hold the offending data entries. Though caution should be exercised when using so many variables to calculate the r2, it has the potential to artificially inflate the values calculated without bringing greater accuracy. The method adjusts and accounts for limited inclusion of variables.
# Out:
# R-squared ALL Features: 1.0
# R-squared Missing 1 Feature: 1.0
# R-squared Missing 2 Features: 1.0
# R-squared Missing 3 Features: 1.0
# R-squared Missing 4 Features: 1.0

# %%
# Calculate the mean squared error.
# All the independent variables
mse_all = np.mean((y_pred_all - y)**2)

# Only four independent variables
mse_missing_1 = np.mean((y_pred_missing_1 - y)**2)

# Only three independent variable
mse_missing_2 = np.mean((y_pred_missing_2 - y)**2)

# Only two independent variables
mse_missing_3 = np.mean((y_pred_missing_3 - y)**2)

# Only one independent variable
mse_missing_4 = np.mean((y_pred_missing_4 - y)**2)

# %%
# Print the mean squared error.
# All the independent variables
print('MSE ALL Features:', mse_all)

# Only four independent variables
print('MSE Missing 1 Feature:', mse_missing_1)

# Only three independent variable
print('MSE Missing 2 Features:', mse_missing_2)

# Only two independent variable
print('MSE Missing 3 Features:', mse_missing_3)

# Only one independent variable
print('MSE Missing 4 Features:', mse_missing_4)
# Out:
# MSE ALL Features: 3.1003271810529053e-31
# MSE Missing 1 Feature: 3.1003271810529053e-31
# MSE Missing 2 Features: 3.1003271810529053e-31
# MSE Missing 3 Features: 3.1003271810529053e-31
# MSE Missing 4 Features: 3.1003271810529053e-31

# %%
# Remove outliers

# %%
# Multi-colinearity

# %%
# step 2, Explore the data set to understand the features
# find optimum number of features/columns and justify your assumption(s

# Visualise engine data with histogram.
plt.figure(figsize=(12, 12))

# Plot the raw data with outliers.
plt.subplot(1, 4, 1)
sns.boxplot(data = df['Coolant pressure'])
plt.title('cool pres')

plt.subplot(1, 4, 2)
sns.boxplot(data = df['Lub oil pressure'])
plt.title('Lub oil p')

plt.subplot(1, 4, 3)
sns.boxplot(data = df['Fuel pressure'])
plt.title('Fuel pressure')

plt.subplot(1, 4, 4)
sns.histplot(data = df['Engine rpm'], kde = True)
plt.title('engine rpm')

plt.show()

# %%
# Visualise engine data with histogram.
plt.figure(figsize=(12, 9))

# Plot the raw data with outliers.
plt.subplot(1, 3, 1)
sns.boxplot(data = df['lub oil temp'])
plt.title('lot')

plt.subplot(1, 3, 2)
sns.boxplot(data = df['Coolant temp'])
plt.title('cool temp')

plt.subplot(1, 3, 3)
sns.histplot(data = df['Engine rpm'])
plt.title('lo temp')
plt.show()

plt.tight_layout()

# Has only the data that tracks the engine failure been supplied?
# It seems that lub oil temp has been extremely high since the engine was turned on.

# %%
# Dependent variable is y. The testing group.
# Independent variables are X. The training group.

# %%
#.# Determine if there is multi-colinaearity and if so...

# %%
# Determine the importance of features using MI
# Perform feature selection with RFE
# Create a heatmap to evaluate possible correlation coefficients
# Create target and input featires of the data frame (not a model creation or application of another model) - selecting the most important columns to use to predict the -y-

# Deal with feature, transformation, creation, extraction, selection - the 'leveraging business knowledge' aspect when there are multiple columns (eg format)
# evaluate, tune, train, select, prepare for the system of choice environment etc.
#

# %%
#2. View the DataFrame and perform EDA, including identifying missing or duplicate values.

# Plot the results.
plt.figure(figsize=(15, 7))

# Plot the raw data with outliers.
plt.subplot(1, 2, 1)
plt.scatter(df['Engine rpm'], df['Coolant temp'], label='Data')
plt.ylim(50, 200)  # Fix the y-axis scale.
plt.title('Raw data')
plt.legend()

# use the method implemented for number of children with bmi.

# %%
#3. Generate the descriptive statistics of the data, including:
#observing the mean for each feature
df.describe()

# Plot the IQR anomaly detection

# Assumptions (i) at low engine rpm, there is too little lubricant used - friction and over-heating are probable consequences. Regardless, the engine is often running more than 14* the minimum (ii) Immense variation in fuel pressure.The low level is detrimental to the fuel pump system and fuel consumption efficincies, which is also a problem for emissions. The higher-level suggests fuel or pump issues because there are inefficiencies in its use (iii) Head gaskets might be failing when the coolant pressure is high but it is difficult to know because it leads to overheating, as does a low level, when there are problems with leaks or filtration (iv) degredation of the engine is indicated by higher temp because the properties of the oil cannot perform adequately at excessive temperatures, although inadequacy is also shown by lower temperatures. (v)

# The problem statement is that the extreme lub oil temp is > 3 std dev above the base temp at 75% mark and the same issue is causing a similair disturbance in the coolant pressure - resulting in an exponentially high maximum coolant temperature. The engine is thus forced to work excessively hard. Whatever is causing the error effects all features at the upper extremes.
# Out:
#          Engine rpm  Lub oil pressure  Fuel pressure  Coolant pressure  \
# count  19535.000000      19535.000000   19535.000000      19535.000000
# mean     791.239263          3.303775       6.655615          2.335369
# std      267.611193          1.021643       2.761021          1.036382
# min       61.000000          0.003384       0.003187          0.002483
# 25%      593.000000          2.518815       4.916886          1.600466
# 50%      746.000000          3.162035       6.201720          2.166883
# 75%      934.000000          4.055272       7.744973          2.848840
# max     2239.000000          7.265566      21.138326          7.478505
#
#        lub oil temp  Coolant temp
# count  19535.000000  19535.000000
# mean      77.643420     78.427433
# std        3.110984      6.206749
# min       71.321974     61.673325
# 25%       75.725990     73.895421
# 50%       76.817350     78.346662
# 75%       78.071691     82.915411
# max       89.580796    195.527912

# %%
#3. Generate the descriptive statistics of the data, including:
#identifying the media
df.median()
df.isnull().sum()

# label =

# Plot the anomaly tech that uses this
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-56642dabdb90> in <cell line: 3>()
#       1 #3. Generate the descriptive statistics of the data, including:
#       2 #identifying the media
# ----> 3 df.median()
#       4 df.isnull().sum()
#       5
#
# NameError: name 'df' is not defined

# %%
#3. Generate the descriptive statistics of the data, including:
#idenitfying the range values beyond the 95th percentile for at least two features.
df.quantile(0.95)
# Out:
# Engine rpm          1324.000000
# Lub oil pressure       5.058040
# Fuel pressure         12.208475
# Coolant pressure       4.438415
# lub oil temp          84.940778
# Coolant temp          88.612891
# Name: 0.95, dtype: float64

# %%
4.1.2 identifying the relevant input features
- employ preprocessing and feature engineering
4.1.4 data cleaning
4.1.8
perform model training, anomaly detection, post-processing, and refinement.
5.1.2 z-scores
5.1.3 to visualise anomalies and create new columns
5.2.2 wonderful anomaly detection algorithm, and anomaly detection with k-means()
- employ preprocessing and feature engineering
4.1.8

# %%
#4. Visualise the data to determine the distribution and extreme values.

# %% [markdown]
# # Reflect
#
# Write a brief paragraph highlighting your process and the rationale to showcase critical thinking and problem-solving.
#
# > Anomaly detection, or outlier detection, is the identification of observations, events or data points that deviate from what is usual, standard or expected, making them inconsistent with the rest of a data set. Removal of these points can result in an imbalanced dataset, which can make any remaining irregularities difficult to disstinguish.dto normal instances, causing datasets to be imbalanced. It is often applied to time-series data.

# %% [markdown]
# ### Reference:
# Devabrat, M., 2022. Predictive Maintenance on Ship's Main Engine using AI. Available at: https://dx.doi.org/10.21227/g3za-v415. [Accessed 5 March 2024]
